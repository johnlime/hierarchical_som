# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Pose-PPO-Somatotopic Model Test

# %%
ppo_df = pd.read_csv("../libraries/RlkitExtension/data/PPOCartpole-v1/PPOCartpole-v1_2021_02_24_15_23_08_0000--s-0/progress.csv", encoding='utf-8')
ppo_df.keys()
# Out:
# Index(['replay_buffer/size', 'trainer/VF Loss', 'trainer/Policy Loss',
#        'trainer/V Predictions Mean', 'trainer/V Predictions Std',
#        'trainer/V Predictions Max', 'trainer/V Predictions Min',
#        'trainer/V Target Mean', 'trainer/V Target Std', 'trainer/V Target Max',
#        'trainer/V Target Min', 'trainer/Policy Gradients Mean',
#        'trainer/Policy Gradients Std', 'trainer/Policy Gradients Max',
#        'trainer/Policy Gradients Min', 'trainer/Value Gradients Mean',
#        'trainer/Value Gradients Std', 'trainer/Value Gradients Max',
#        'trainer/Value Gradients Min', 'trainer/Policy KL Mean',
#        'trainer/Policy KL Std', 'trainer/Policy KL Max',
#        'trainer/Policy KL Min', 'trainer/Policy Entropy Mean',
#        'trainer/Policy Entropy Std', 'trainer/Policy Entropy Max',
#        'trainer/Policy Entropy Min', 'trainer/New Log Pis Mean',
#        'trainer/New Log Pis Std', 'trainer/New Log Pis Max',
#        'trainer/New Log Pis Min', 'trainer/Old Log Pis Mean',
#        'trainer/Old Log Pis Std', 'trainer/Old Log Pis Max',
#        'trainer/Old Log Pis Min', 'exploration/num steps total',
#        'exploration/num paths total', 'exploration/path length Mean',
#        'exploration/path length Std', 'exploration/path length Max',
#        'exploration/path length Min', 'exploration/Rewards Mean',
#        'exploration/Rewards Std', 'exploration/Rewards Max',
#        'exploration/Rewards Min', 'exploration/Returns Mean',
#        'exploration/Returns Std', 'exploration/Returns Max',
#        'exploration/Returns Min', 'exploration/Actions Mean',
#        'exploration/Actions Std', 'exploration/Actions Max',
#        'exploration/Actions Min', 'exploration/Num Paths',
#        'exploration/Average Returns',
#        'exploration/agent_infos/final/log_prob Mean',
#        'exploration/agent_infos/final/log_prob Std',
#        'exploration/agent_infos/final/log_prob Max',
#        'exploration/agent_infos/final/log_prob Min',
#        'exploration/agent_infos/initial/log_prob Mean',
#        'exploration/agent_infos/initial/log_prob Std',
#        'exploration/agent_infos/initial/log_prob Max',
#        'exploration/agent_infos/initial/log_prob Min',
#        'exploration/agent_infos/log_prob Mean',
#        'exploration/agent_infos/log_prob Std',
#        'exploration/agent_infos/log_prob Max',
#        'exploration/agent_infos/log_prob Min', 'evaluation/num steps total',
#        'evaluation/num paths total', 'evaluation/path length Mean',
#        'evaluation/path length Std', 'evaluation/path length Max',
#        'evaluation/path length Min', 'evaluation/Rewards Mean',
#        'evaluation/Rewards Std', 'evaluation/Rewards Max',
#        'evaluation/Rewards Min', 'evaluation/Returns Mean',
#        'evaluation/Returns Std', 'evaluation/Returns Max',
#        'evaluation/Returns Min', 'evaluation/Actions Mean',
#        'evaluation/Actions Std', 'evaluation/Actions Max',
#        'evaluation/Actions Min', 'evaluation/Num Paths',
#        'evaluation/Average Returns', 'time/data storing (s)',
#        'time/evaluation sampling (s)', 'time/exploration sampling (s)',
#        'time/logging (s)', 'time/saving (s)', 'time/training (s)',
#        'time/epoch (s)', 'time/total (s)', 'Epoch'],
#       dtype='object')

# %%
plt.plot(ppo_df["trainer/VF Loss"])

# %%
plt.plot(ppo_df["trainer/Policy Loss"])

# %%
plt.plot(ppo_df["exploration/Returns Mean"])

# %%
plt.plot(ppo_df["evaluation/Returns Mean"])
