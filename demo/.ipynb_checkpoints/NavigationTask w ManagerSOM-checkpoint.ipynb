# %% [markdown]
# # Navigation Task

# %%
import torch
import numpy as np
import math
import random
import matplotlib.pyplot as plt
from model.kohonen_som import KohonenSOM
from model.manager_som_position import ManagerSOMPosition, ManagerSOMPositionAllNeighbor
from custom_env.navigation_task import NavigationTask
# %matplotlib inline
# Out:
# path exception

# %%
x = torch.rand(1000, 2)-0.5
maxitr = 10**4*5
som = KohonenSOM(total_nodes=100, node_size=2, update_iterations=maxitr)
reshaped = som.w.reshape(10, 10, 2)
for v in range(10):
    plt.plot(reshaped[:, v, 0].numpy(), reshaped[:, v, 1].numpy(), marker='None', linestyle='-', color='blue')
    plt.plot(reshaped[v, :, 0].numpy(), reshaped[v, :, 1].numpy(), marker='None', linestyle='-', color='blue')
plt.plot(som.w[:, 0].numpy(), som.w[:, 1].numpy(), marker='o', color='blue')
plt.show()
for t in range(maxitr):
    a, c = som.update(x, t, 0)
    
plt.plot(x[:, 0].numpy(), x[:, 1].numpy(), marker='v', linestyle='None', color='orange')
reshaped = som.w.reshape(10, 10, 2)
for v in range(10):
    plt.plot(reshaped[:, v, 0].numpy(), reshaped[:, v, 1].numpy(), marker='None', linestyle='-', color='blue')
    plt.plot(reshaped[v, :, 0].numpy(), reshaped[v, :, 1].numpy(), marker='None', linestyle='-', color='blue')
plt.plot(som.w[:, 0].numpy(), som.w[:, 1].numpy(), marker='o', color='blue')
plt.show()
som.w
# Out:
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# tensor([[ 0.4216, -0.4053],
#         [ 0.4313, -0.3553],
#         [ 0.4273, -0.2697],
#         [ 0.4248, -0.1547],
#         [ 0.4234, -0.0662],
#         [ 0.4299,  0.0096],
#         [ 0.4152,  0.1141],
#         [ 0.4252,  0.2252],
#         [ 0.4075,  0.3290],
#         [ 0.3972,  0.3773],
#         [ 0.3735, -0.4267],
#         [ 0.3709, -0.3748],
#         [ 0.3833, -0.2688],
#         [ 0.3682, -0.1737],
#         [ 0.3688, -0.0721],
#         [ 0.3690,  0.0255],
#         [ 0.3602,  0.1266],
#         [ 0.3686,  0.2297],
#         [ 0.3600,  0.3448],
#         [ 0.3513,  0.3957],
#         [ 0.2943, -0.4392],
#         [ 0.2804, -0.3829],
#         [ 0.2784, -0.3015],
#         [ 0.2585, -0.1928],
#         [ 0.2534, -0.0695],
#         [ 0.2504,  0.0421],
#         [ 0.2583,  0.1287],
#         [ 0.2644,  0.2277],
#         [ 0.2549,  0.3479],
#         [ 0.2632,  0.4124],
#         [ 0.1710, -0.4390],
#         [ 0.1500, -0.3770],
#         [ 0.1679, -0.2829],
#         [ 0.1335, -0.1712],
#         [ 0.1200, -0.0846],
#         [ 0.1428,  0.0214],
#         [ 0.1528,  0.1420],
#         [ 0.1622,  0.2656],
#         [ 0.1454,  0.3643],
#         [ 0.1583,  0.4178],
#         [ 0.0630, -0.4246],
#         [ 0.0489, -0.3740],
#         [ 0.0561, -0.2808],
#         [ 0.0282, -0.1753],
#         [ 0.0322, -0.0783],
#         [ 0.0286,  0.0057],
#         [ 0.0335,  0.1448],
#         [ 0.0367,  0.2461],
#         [ 0.0277,  0.3756],
#         [ 0.0329,  0.4150],
#         [-0.0327, -0.4232],
#         [-0.0402, -0.3641],
#         [-0.0735, -0.2729],
#         [-0.0693, -0.1832],
#         [-0.1084, -0.0754],
#         [-0.0988,  0.0088],
#         [-0.0737,  0.1180],
#         [-0.0533,  0.2590],
#         [-0.0823,  0.3638],
#         [-0.0891,  0.4148],
#         [-0.1372, -0.4292],
#         [-0.1700, -0.3606],
#         [-0.1762, -0.2626],
#         [-0.1954, -0.1950],
#         [-0.2041, -0.0806],
#         [-0.2024,  0.0463],
#         [-0.1853,  0.1468],
#         [-0.1678,  0.2497],
#         [-0.1735,  0.3494],
#         [-0.1916,  0.4104],
#         [-0.2663, -0.4258],
#         [-0.2611, -0.3596],
#         [-0.2606, -0.2752],
#         [-0.2802, -0.1588],
#         [-0.2909, -0.0428],
#         [-0.2906,  0.0547],
#         [-0.2889,  0.1680],
#         [-0.2734,  0.2648],
#         [-0.2817,  0.3683],
#         [-0.2832,  0.4147],
#         [-0.3655, -0.4208],
#         [-0.3496, -0.3654],
#         [-0.3745, -0.2682],
#         [-0.3683, -0.1489],
#         [-0.3702, -0.0499],
#         [-0.3863,  0.0682],
#         [-0.3891,  0.1644],
#         [-0.3818,  0.2716],
#         [-0.3684,  0.3700],
#         [-0.3562,  0.4159],
#         [-0.4076, -0.4001],
#         [-0.4178, -0.3486],
#         [-0.4271, -0.2937],
#         [-0.4228, -0.1789],
#         [-0.4283, -0.0398],
#         [-0.4396,  0.0534],
#         [-0.4401,  0.1790],
#         [-0.4353,  0.2853],
#         [-0.4232,  0.3568],
#         [-0.4070,  0.4065]])

# %% [markdown]
# ## Manager Self Organizing Map

# %%
manager_maxitr = 10 ** 3
maxtime = 100
epsilon = 0.2
torch.manual_seed(0)
random.seed(0)

manager_som = ManagerSOMPosition(total_nodes=100, state_som = som, worker_som=som, update_iterations=manager_maxitr)
task = NavigationTask()

for epoch in range(manager_maxitr):
    # for visualization
    total_return = 0
    state_trajectory = []
    obs = task.state()
    
    for t in range(maxtime):
        obs = task.state()
        
        # epsilon greedy
        if random.random() > epsilon:
            action_index = manager_som.get_action(som.location[som.select_winner(obs)]) # deterministic

        else:
            action_index = random.randrange(som.total_nodes)
        
        # step forward
        reward, next_obs = task.step(som.w[action_index])
        
        # online training
        manager_som.action_q_learning(
            current_state_position = som.location[som.select_winner(obs)],
            next_state_position = som.location[som.select_winner(next_obs)],
            action_index = action_index,
            reward = reward,
            t = epoch)
        
        obs = next_obs
        state_trajectory.append(np.array(obs))
        total_return += (0.9 ** t) * reward
        
    if epoch % 100 == 99:
        plt.plot(np.array(state_trajectory)[:, 0], np.array(state_trajectory)[:, 1], marker='.', linestyle='-', color='blue')
        plt.plot(0.0, 0.0, marker='v', linestyle='None', color='orange')
        plt.plot(np.array(task.goal)[0], np.array(task.goal)[1], marker='v', linestyle='None', color='red')
        plt.show()
        print(epoch, total_return)
    
    task.reset()
# Out:
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 99 30.53758164767407
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 199 27.83645108062619
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 299 27.723630529319575
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 399 27.05333153846186
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 499 30.5980022740431
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 599 23.179092238207975
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 699 29.157854616304974
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 799 26.859648835187716
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 899 30.25080201884043
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 999 28.33789751654715

# %%
# for visualization
total_return = 0
state_trajectory = []

for t in range(maxtime): 
    obs = task.state()
    action_index = manager_som.get_action(som.location[som.select_winner(obs)]) # deterministic

    # step forward
    reward, next_obs = task.step(som.w[action_index])

    obs = next_obs
    state_trajectory.append(np.array(obs))
    total_return += (0.9 ** t) * reward

plt.plot(np.array(state_trajectory)[:, 0], np.array(state_trajectory)[:, 1], marker='.', linestyle='-', color='blue')
plt.plot(0.0, 0.0, marker='v', linestyle='None', color='orange')
plt.plot(np.array(task.goal)[0], np.array(task.goal)[1], marker='v', linestyle='None', color='red')
plt.show()
print(total_return)

task.reset()
# Out:
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 31.107210111762463

# %%
manager_maxitr = 10 ** 3
maxtime = 100
epsilon = 0.2
torch.manual_seed(0)
random.seed(0)

manager_som = ManagerSOMPositionAllNeighbor(total_nodes=100, state_som = som, worker_som=som, update_iterations=manager_maxitr)
task = NavigationTask()

for epoch in range(manager_maxitr):
    # for visualization
    total_return = 0
    state_trajectory = []
    obs = task.state()
    
    for t in range(maxtime):
        obs = task.state()
        
        # epsilon greedy
        if random.random() > epsilon:
            action_index = manager_som.get_action(som.location[som.select_winner(obs)]) # deterministic

        else:
            action_index = random.randrange(som.total_nodes)
        
        # step forward
        reward, next_obs = task.step(som.w[action_index])
        
        # online training
        manager_som.action_q_learning(
            current_state_position = som.location[som.select_winner(obs)],
            next_state_position = som.location[som.select_winner(next_obs)],
            action_index = action_index,
            reward = reward,
            t = epoch)
        
        obs = next_obs
        state_trajectory.append(np.array(obs))
        total_return += (0.9 ** t) * reward
        
    if epoch % 100 == 99:
        plt.plot(np.array(state_trajectory)[:, 0], np.array(state_trajectory)[:, 1], marker='.', linestyle='-', color='blue')
        plt.plot(0.0, 0.0, marker='v', linestyle='None', color='orange')
        plt.plot(np.array(task.goal)[0], np.array(task.goal)[1], marker='v', linestyle='None', color='red')
        plt.show()
        print(epoch, total_return)
    
    task.reset()
# Out:
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 99 30.57663821663726
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 199 27.909041074979314
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 299 27.72315196618636
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 399 27.05329773943861
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 499 30.598371878496817
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 599 23.179133298957026
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 699 29.157846975101606
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 799 26.859527710542377
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 899 30.249467389940122
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 999 28.337883304131243

# %%
# for visualization
total_return = 0
state_trajectory = []

for t in range(maxtime): 
    obs = task.state()
    action_index = manager_som.get_action(som.location[som.select_winner(obs)]) # deterministic

    # step forward
    reward, next_obs = task.step(som.w[action_index])

    obs = next_obs
    state_trajectory.append(np.array(obs))
    total_return += (0.9 ** t) * reward

plt.plot(np.array(state_trajectory)[:, 0], np.array(state_trajectory)[:, 1], marker='.', linestyle='-', color='blue')
plt.plot(0.0, 0.0, marker='v', linestyle='None', color='orange')
plt.plot(np.array(task.goal)[0], np.array(task.goal)[1], marker='v', linestyle='None', color='red')
plt.show()
print(total_return)

task.reset()
# Out:
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/kohonen_som.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# /Volumes/Macintosh HD - Data/Users/johnlime/Documents/MultipleApps/h_som/model/manager_som_position.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# 31.107210111762463

# %% [markdown]
# ## Visualization of SOMs

# %%
from IPython.display import Image

def visualize_som(som, columns, labels = ["", ""], dim = 10):
    reshaped_x = som.w[:, columns[0]].reshape(dim, dim)
    reshaped_y = som.w[:, columns[1]].reshape(dim, dim)
    for v in range(dim):
        plt.plot(reshaped_x[:, v].numpy(), reshaped_y[:, v].numpy(), marker='None', linestyle='-', color='blue')
        plt.plot(reshaped_x[v, :].numpy(), reshaped_y[v, :].numpy(), marker='None', linestyle='-', color='blue')
    plt.plot(som.w[:, columns[0]].numpy(), som.w[:, columns[1]].numpy(), marker='o', color='blue')
    plt.xlabel(labels[0])
    plt.ylabel(labels[1])
    plt.show()

# %%
manager_som.w.shape
# Out:
# torch.Size([100, 102])

# %%
for i in range(100):
    print(i, som.w[i])
    plt.imshow(manager_som.w[:, i].reshape(10, 10), cmap='hot', interpolation='nearest')
    plt.show()
# Out:
# 0 tensor([ 0.4216, -0.4053])
# 1 tensor([ 0.4313, -0.3553])
# 2 tensor([ 0.4273, -0.2697])
# 3 tensor([ 0.4248, -0.1547])
# 4 tensor([ 0.4234, -0.0662])
# 5 tensor([0.4299, 0.0096])
# 6 tensor([0.4152, 0.1141])
# 7 tensor([0.4252, 0.2252])
# 8 tensor([0.4075, 0.3290])
# 9 tensor([0.3972, 0.3773])
# 10 tensor([ 0.3735, -0.4267])
# 11 tensor([ 0.3709, -0.3748])
# 12 tensor([ 0.3833, -0.2688])
# 13 tensor([ 0.3682, -0.1737])
# 14 tensor([ 0.3688, -0.0721])
# 15 tensor([0.3690, 0.0255])
# 16 tensor([0.3602, 0.1266])
# 17 tensor([0.3686, 0.2297])
# 18 tensor([0.3600, 0.3448])
# 19 tensor([0.3513, 0.3957])
# 20 tensor([ 0.2943, -0.4392])
# 21 tensor([ 0.2804, -0.3829])
# 22 tensor([ 0.2784, -0.3015])
# 23 tensor([ 0.2585, -0.1928])
# 24 tensor([ 0.2534, -0.0695])
# 25 tensor([0.2504, 0.0421])
# 26 tensor([0.2583, 0.1287])
# 27 tensor([0.2644, 0.2277])
# 28 tensor([0.2549, 0.3479])
# 29 tensor([0.2632, 0.4124])
# 30 tensor([ 0.1710, -0.4390])
# 31 tensor([ 0.1500, -0.3770])
# 32 tensor([ 0.1679, -0.2829])
# 33 tensor([ 0.1335, -0.1712])
# 34 tensor([ 0.1200, -0.0846])
# 35 tensor([0.1428, 0.0214])
# 36 tensor([0.1528, 0.1420])
# 37 tensor([0.1622, 0.2656])
# 38 tensor([0.1454, 0.3643])
# 39 tensor([0.1583, 0.4178])
# 40 tensor([ 0.0630, -0.4246])
# 41 tensor([ 0.0489, -0.3740])
# 42 tensor([ 0.0561, -0.2808])
# 43 tensor([ 0.0282, -0.1753])
# 44 tensor([ 0.0322, -0.0783])
# 45 tensor([0.0286, 0.0057])
# 46 tensor([0.0335, 0.1448])
# 47 tensor([0.0367, 0.2461])
# 48 tensor([0.0277, 0.3756])
# 49 tensor([0.0329, 0.4150])
# 50 tensor([-0.0327, -0.4232])
# 51 tensor([-0.0402, -0.3641])
# 52 tensor([-0.0735, -0.2729])
# 53 tensor([-0.0693, -0.1832])
# 54 tensor([-0.1084, -0.0754])
# 55 tensor([-0.0988,  0.0088])
# 56 tensor([-0.0737,  0.1180])
# 57 tensor([-0.0533,  0.2590])
# 58 tensor([-0.0823,  0.3638])
# 59 tensor([-0.0891,  0.4148])
# 60 tensor([-0.1372, -0.4292])
# 61 tensor([-0.1700, -0.3606])
# 62 tensor([-0.1762, -0.2626])
# 63 tensor([-0.1954, -0.1950])
# 64 tensor([-0.2041, -0.0806])
# 65 tensor([-0.2024,  0.0463])
# 66 tensor([-0.1853,  0.1468])
# 67 tensor([-0.1678,  0.2497])
# 68 tensor([-0.1735,  0.3494])
# 69 tensor([-0.1916,  0.4104])
# 70 tensor([-0.2663, -0.4258])
# 71 tensor([-0.2611, -0.3596])
# 72 tensor([-0.2606, -0.2752])
# 73 tensor([-0.2802, -0.1588])
# 74 tensor([-0.2909, -0.0428])
# 75 tensor([-0.2906,  0.0547])
# 76 tensor([-0.2889,  0.1680])
# 77 tensor([-0.2734,  0.2648])
# 78 tensor([-0.2817,  0.3683])
# 79 tensor([-0.2832,  0.4147])
# 80 tensor([-0.3655, -0.4208])
# 81 tensor([-0.3496, -0.3654])
# 82 tensor([-0.3745, -0.2682])
# 83 tensor([-0.3683, -0.1489])
# 84 tensor([-0.3702, -0.0499])
# 85 tensor([-0.3863,  0.0682])
# 86 tensor([-0.3891,  0.1644])
# 87 tensor([-0.3818,  0.2716])
# 88 tensor([-0.3684,  0.3700])
# 89 tensor([-0.3562,  0.4159])
# 90 tensor([-0.4076, -0.4001])
# 91 tensor([-0.4178, -0.3486])
# 92 tensor([-0.4271, -0.2937])
# 93 tensor([-0.4228, -0.1789])
# 94 tensor([-0.4283, -0.0398])
# 95 tensor([-0.4396,  0.0534])
# 96 tensor([-0.4401,  0.1790])
# 97 tensor([-0.4353,  0.2853])
# 98 tensor([-0.4232,  0.3568])
# 99 tensor([-0.4070,  0.4065])

# %%
visualize_som(manager_som, [0, 1])
